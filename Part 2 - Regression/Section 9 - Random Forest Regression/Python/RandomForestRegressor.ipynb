# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;
# Out:
# C:\Users\rocky.kumar\AppData\Local\Temp\ipykernel_17216\1710386541.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd;

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.ensemble import RandomForestRegressor
reggressor = RandomForestRegressor(n_estimators=10, random_state=0)
reggressor.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
reggressor.predict([[6.5]])
# Out:
# array([167000.])

# %%
X_grid = np.arange(min(X), max(X), step=0.1)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X,y, color='red')
plt.plot(X_grid, reggressor.predict(X_grid), color='blue')
plt.show()
# Out:
# C:\Users\rocky.kumar\AppData\Local\Temp\ipykernel_17216\3501744397.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), step=0.1)
